# %% [markdown]
# # House Sales in King County, USA

# %% [markdown]
# ##### This dataset contains house sale prices for King County, which includes Seattle. It includes homes sold between May 2014 and May 2015.

# %% [markdown]
# <b>id</b> :a notation for a house
#
# <b> date</b>: Date house was sold
#
#
# <b>price</b>: Price is prediction target
#
#
# <b>bedrooms</b>: Number of Bedrooms/House
#
#
# <b>bathrooms</b>: Number of bathrooms/bedrooms
#
# <b>sqft_living</b>: square footage of the home
#
# <b>sqft_lot</b>: square footage of the lot
#
#
# <b>floors</b> :Total floors (levels) in house
#
#
# <b>waterfront</b> :House which has a view to a waterfront
#
#
# <b>view</b>: Has been viewed
#
#
# <b>condition</b> :How good the condition is  Overall
#
# <b>grade</b>: overall grade given to the housing unit, based on King County grading system
#
#
# <b>sqft_above</b> :square footage of house apart from basement
#
#
# <b>sqft_basement</b>: square footage of the basement
#
# <b>yr_built</b> :Built Year
#
#
# <b>yr_renovated</b> :Year when house was renovated
#
# <b>zipcode</b>:zip code
#
#
# <b>lat</b>: Latitude coordinate
#
# <b>long</b>: Longitude coordinate
#
# <b>sqft_living15</b> :Living room area in 2015(implies-- some renovations) This might or might not have affected the lotsize area
#
#
# <b>sqft_lot15</b> :lotSize area in 2015(implies-- some renovations)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %% [markdown]
# ### Importing data

# %%
file_name='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv'
df=pd.read_csv(file_name)

# %%
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 21608       21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609       21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610       21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611       21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612       21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 21608         1530      1131     3.0           0  ...      8        1530
# 21609         2310      5813     2.0           0  ...      8        2310
# 21610         1020      1350     2.0           0  ...      7        1020
# 21611         1600      2388     2.0           0  ...      8        1600
# 21612         1020      1076     2.0           0  ...      7        1020
#
# ...

# %%
df.describe(include="all")
# Out:
#          Unnamed: 0            id             date         price  \
# count   21613.00000  2.161300e+04            21613  2.161300e+04
# unique          NaN           NaN              372           NaN
# top             NaN           NaN  20140623T000000           NaN
# freq            NaN           NaN              142           NaN
# mean    10806.00000  4.580302e+09              NaN  5.400881e+05
# std      6239.28002  2.876566e+09              NaN  3.671272e+05
# min         0.00000  1.000102e+06              NaN  7.500000e+04
# 25%      5403.00000  2.123049e+09              NaN  3.219500e+05
# 50%     10806.00000  3.904930e+09              NaN  4.500000e+05
# 75%     16209.00000  7.308900e+09              NaN  6.450000e+05
# max     21612.00000  9.900000e+09              NaN  7.700000e+06
#
#             bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count   21600.000000  21603.000000  21613.000000  2.161300e+04  21613.000000
# ...

# %%
df
# Out:
#        Unnamed: 0          id             date      price  bedrooms  \
# 0               0  7129300520  20141013T000000   221900.0       3.0
# 1               1  6414100192  20141209T000000   538000.0       3.0
# 2               2  5631500400  20150225T000000   180000.0       2.0
# 3               3  2487200875  20141209T000000   604000.0       4.0
# 4               4  1954400510  20150218T000000   510000.0       3.0
# 5               5  7237550310  20140512T000000  1225000.0       4.0
# 6               6  1321400060  20140627T000000   257500.0       3.0
# 7               7  2008000270  20150115T000000   291850.0       3.0
# 8               8  2414600126  20150415T000000   229500.0       3.0
# 9               9  3793500160  20150312T000000   323000.0       3.0
# 10             10  1736800520  20150403T000000   662500.0       3.0
# 11             11  9212900260  20140527T000000   468000.0       2.0
# 12             12   114101516  20140528T000000   310000.0       3.0
# ...

# %% [markdown]
# ## Data Cleaning

# %%
df
# Out:
#        Unnamed: 0          id             date      price  bedrooms  \
# 0               0  7129300520  20141013T000000   221900.0       3.0
# 1               1  6414100192  20141209T000000   538000.0       3.0
# 2               2  5631500400  20150225T000000   180000.0       2.0
# 3               3  2487200875  20141209T000000   604000.0       4.0
# 4               4  1954400510  20150218T000000   510000.0       3.0
# 5               5  7237550310  20140512T000000  1225000.0       4.0
# 6               6  1321400060  20140627T000000   257500.0       3.0
# 7               7  2008000270  20150115T000000   291850.0       3.0
# 8               8  2414600126  20150415T000000   229500.0       3.0
# 9               9  3793500160  20150312T000000   323000.0       3.0
# 10             10  1736800520  20150403T000000   662500.0       3.0
# 11             11  9212900260  20140527T000000   468000.0       2.0
# 12             12   114101516  20140528T000000   310000.0       3.0
# ...

# %%
# Removing the Unnamed: 0 and id columns
df.drop(columns=['Unnamed: 0','id'],axis=1,inplace=True)

# %%
df
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000   221900.0       3.0       1.00         1180      5650
# 1      20141209T000000   538000.0       3.0       2.25         2570      7242
# 2      20150225T000000   180000.0       2.0       1.00          770     10000
# 3      20141209T000000   604000.0       4.0       3.00         1960      5000
# 4      20150218T000000   510000.0       3.0       2.00         1680      8080
# 5      20140512T000000  1225000.0       4.0       4.50         5420    101930
# 6      20140627T000000   257500.0       3.0       2.25         1715      6819
# 7      20150115T000000   291850.0       3.0       1.50         1060      9711
# 8      20150415T000000   229500.0       3.0       1.00         1780      7470
# 9      20150312T000000   323000.0       3.0       2.50         1890      6560
# 10     20150403T000000   662500.0       3.0       2.50         3560      9796
# ...

# %%
# Checking for the presence of NaN values in every columns
for col in df.columns:
    print("The number of NaN values in column {} is: {}".format(col,df[col].isnull().sum()))
# Out:
# The number of NaN values in column date is: 0
# The number of NaN values in column price is: 0
# The number of NaN values in column bedrooms is: 13
# The number of NaN values in column bathrooms is: 10
# The number of NaN values in column sqft_living is: 0
# The number of NaN values in column sqft_lot is: 0
# The number of NaN values in column floors is: 0
# The number of NaN values in column waterfront is: 0
# The number of NaN values in column view is: 0
# The number of NaN values in column condition is: 0
# The number of NaN values in column grade is: 0
# The number of NaN values in column sqft_above is: 0
# The number of NaN values in column sqft_basement is: 0
# The number of NaN values in column yr_built is: 0
# The number of NaN values in column yr_renovated is: 0
# The number of NaN values in column zipcode is: 0
# The number of NaN values in column lat is: 0
# The number of NaN values in column long is: 0
# The number of NaN values in column sqft_living15 is: 0
# ...

# %%
# Replacing the NaN values of bedrooms and bathrooms column by their respective average values

df['bedrooms'].replace(np.nan,df['bedrooms'].mean(),inplace=True)
df['bathrooms'].replace(np.nan,df['bathrooms'].mean(),inplace=True)

# %%
# Checking for the presence of NaN values in every columns
for col in df.columns:
    print("The number of NaN values in column {} is: {}".format(col,df[col].isnull().sum()))
# Out:
# The number of NaN values in column date is: 0
# The number of NaN values in column price is: 0
# The number of NaN values in column bedrooms is: 0
# The number of NaN values in column bathrooms is: 0
# The number of NaN values in column sqft_living is: 0
# The number of NaN values in column sqft_lot is: 0
# The number of NaN values in column floors is: 0
# The number of NaN values in column waterfront is: 0
# The number of NaN values in column view is: 0
# The number of NaN values in column condition is: 0
# The number of NaN values in column grade is: 0
# The number of NaN values in column sqft_above is: 0
# The number of NaN values in column sqft_basement is: 0
# The number of NaN values in column yr_built is: 0
# The number of NaN values in column yr_renovated is: 0
# The number of NaN values in column zipcode is: 0
# The number of NaN values in column lat is: 0
# The number of NaN values in column long is: 0
# The number of NaN values in column sqft_living15 is: 0
# ...

# %% [markdown]
# ## Model Development

# %%
# Linear Regression model of sqft_living vs price

lm = LinearRegression()
x = df[['sqft_living']]
y = df['price']
lm.fit(x,y)
yhat = lm.predict([[1180],[2570]])
yhat
# Out:
# array([287555.06702451, 677621.82640197])

# %% [markdown]
# ### Predicted value: 287555.067 , 677621.826
# ### Actual value: 221900 , 538000

# %%
# Linear Regression model of a range of values

x = df[['sqft_living','sqft_lot','sqft_above']]
y = df['price']
lm.fit(x,y)
yhat = lm.predict([[1180,5650,1180]])
yhat
# Out:
# array([286496.02528211])

# %% [markdown]
# # Plots

# %% [markdown]
# ### Regression Plots

# %%
# Regression plot pf bathrooms vs price
sns.regplot(x='bathrooms',y='price',data=df)
plt.ylim(0,)
# Out:
# (0, 8084989.934651333)

# %%
# Regression plot pf sqft_living vs price

sns.regplot(x='sqft_living',y='price',data=df)
plt.ylim(0,)
# Out:
# (0, 8094564.28739064)

# %% [markdown]
# ### Residual Plots

# %%
sns.residplot(df['sqft_living'],df['price'])

# %% [markdown]
# ### Distribution Plots

# %%
ax1 = sns.distplot(df['price'],hist = False,color = "r",label="Actual")

#sns.distplot(yhat,hist=False,color="b",label="Fitted values",ax=ax1)
